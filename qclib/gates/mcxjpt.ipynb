# %%
from qiskit import QuantumRegister, transpile
from mcx import McxVchainDirty, LinearMcx
import mcxog

# %% [markdown]
# Teste para n_controls<3

# %%
num_controls = 2
#num_ancilla = num_controls - 2
num_target_qubit = 2
control_qubits = QuantumRegister(num_controls)
target_qubit = QuantumRegister(num_target_qubit)

mcx_v_chain = McxVchainDirty(num_controls, num_target_qubit=num_target_qubit).definition

#tr_mcx_v_chain = transpile(mcx_v_chain, basis_gates=['u', 'cx'])
mcx_v_chain.decompose().draw('mpl')

# %% [markdown]
# n_controls=3

# %%
num_controls = 3
#num_ancilla = num_controls - 2
num_target_qubit = 2
control_qubits = QuantumRegister(num_controls)
target_qubit = QuantumRegister(num_target_qubit)

mcx_v_chain = McxVchainDirty(num_controls, num_target_qubit=num_target_qubit).definition

#tr_mcx_v_chain = transpile(mcx_v_chain, basis_gates=['u', 'cx'])
mcx_v_chain.decompose().draw('mpl')

# %% [markdown]
# Para n_controls = 4

# %% [markdown]
# Para apenas um target, usando a função original

# %%
num_controls = 4
#num_ancilla = num_controls - 2
num_target_qubit = 1
control_qubits = QuantumRegister(num_controls)
target_qubit = QuantumRegister(num_target_qubit)

mcx_v_chain = mcxog.McxVchainDirty(num_controls).definition

#tr_mcx_v_chain = transpile(mcx_v_chain, basis_gates=['u', 'cx'])
mcx_v_chain.draw('mpl')

# %% [markdown]
# Para um target usando nossa funçao

# %%
num_controls = 4
#num_ancilla = num_controls - 2
num_target_qubit = 1
control_qubits = QuantumRegister(num_controls)
target_qubit = QuantumRegister(num_target_qubit)

mcx_v_chain = McxVchainDirty(num_controls).definition

#tr_mcx_v_chain = transpile(mcx_v_chain, basis_gates=['u', 'cx'])
mcx_v_chain.draw('mpl')

# %% [markdown]
# Para 2 targets

# %%
num_controls = 4
#num_ancilla = num_controls - 2
num_target_qubit = 2
control_qubits = QuantumRegister(num_controls)
target_qubit = QuantumRegister(num_target_qubit)

mcx_v_chain = McxVchainDirty(num_controls, num_target_qubit=num_target_qubit).definition

#tr_mcx_v_chain = transpile(mcx_v_chain, basis_gates=['u', 'cx'])
mcx_v_chain.draw('mpl')

# %% [markdown]
# Para n qubits = 8

# %%
num_controls = 6
#num_ancilla = num_controls - 2
num_target_qubit = 1
control_qubits = QuantumRegister(num_controls)
target_qubit = QuantumRegister(num_target_qubit)

mcx_v_chain = mcxog.McxVchainDirty(num_controls, action_only=True).definition

#tr_mcx_v_chain = transpile(mcx_v_chain, basis_gates=['u', 'cx'])
mcx_v_chain.draw('mpl')

# %%
num_controls = 6
#num_ancilla = num_controls - 2
num_target_qubit = 1
control_qubits = QuantumRegister(num_controls)
target_qubit = QuantumRegister(num_target_qubit)

mcx_v_chain = McxVchainDirty(num_controls, action_only=True).definition

#tr_mcx_v_chain = transpile(mcx_v_chain, basis_gates=['u', 'cx'])
mcx_v_chain.draw('mpl')

# %% [markdown]
# ## Testando o Linear mcx

# %%
num_controls = 6
#num_ancilla = num_controls - 2
num_target_qubit = 1
control_qubits = QuantumRegister(num_controls)
target_qubit = QuantumRegister(num_target_qubit)

mcx_v_chain = mcxog.LinearMcx(num_controls, action_only=True).definition

#tr_mcx_v_chain = transpile(mcx_v_chain, basis_gates=['u', 'cx'])
mcx_v_chain.draw('mpl')

# %%
num_controls = 6
#num_ancilla = num_controls - 2
num_target_qubit = 1
control_qubits = QuantumRegister(num_controls)
target_qubit = QuantumRegister(num_target_qubit)

mcx_v_chain = LinearMcx(num_controls).definition

#tr_mcx_v_chain = transpile(mcx_v_chain, basis_gates=['u', 'cx'])
mcx_v_chain.draw('mpl')
